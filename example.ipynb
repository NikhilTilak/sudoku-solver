# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread
from skimage.color import rgb2gray
from processImage import get_subimage, process_image, plot_subimages

# %% [markdown]
# ## Example 1: A good quality, straight image from the internet.

# %%
fp=".\sudoku_test.png"

# %%
image = imread(fp)
# image = imread(".\sudoku.jpg")
image = rgb2gray(image[:,:,:3])
plt.imshow(image, cmap='gray')
plt.show()

# %%
plot_subimages(image)
# Out:
# True

# %%
s=process_image(fp)
s
# Out:
# c:\Users\nikhi_ntf2doa\anaconda3\envs\data_sci\lib\site-packages\skimage\filters\thresholding.py:370: RuntimeWarning: invalid value encountered in divide
#   mean1 = np.cumsum(counts * bin_centers) / weight1
# 3/3 [==============================] - 0s 2ms/step
# [[5 3 0 0 7 0 0 0 0]
#  [6 0 0 1 9 5 0 0 0]
#  [0 9 8 0 0 0 0 6 0]
#  [8 0 0 0 6 0 0 0 3]
#  [4 0 0 8 0 3 0 0 1]
#  [7 0 0 0 2 0 0 0 6]
#  [0 6 0 0 0 0 2 8 0]
#  [0 0 0 4 0 9 0 0 5]
#  [0 0 0 0 8 0 0 7 9]]

# %% [markdown]
# ## Example 2: From unwarped image

# %%
fp=".\sudoku_wiki_unwarped.png"

image = imread(fp)
image = rgb2gray(image[:,:,:3])
plt.imshow(image, cmap='gray')
plt.show()

# %%
plot_subimages(image)
# Out:
# True

# %%
s=process_image(fp)
s
# Out:
# 3/3 [==============================] - 0s 1ms/step
# [[0 0 8 8 2 8 2 0 8]
#  [0 8 8 3 3 0 0 8 8]
#  [8 0 8 8 8 8 8 0 8]
#  [8 0 0 0 0 0 0 0 8]
#  [8 0 8 8 8 8 0 0 0]
#  [0 3 3 0 8 3 8 8 0]
#  [0 0 0 0 0 0 8 8 0]
#  [0 8 0 8 3 8 0 3 8]
#  [0 8 8 8 8 0 8 0 8]]
